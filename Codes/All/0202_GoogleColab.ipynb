# %% [markdown]
# # Section 1
# Simple Linux Commands

# %%
! ls
# Out:
# sample_data

# %%
! cat /proc/cpuinfo

# %%
# !cat /proc/meminfo

# %% [markdown]
# This is a text cell, where I can write in **bold**
# I cna also write in $\LaTeX$

# %%
! ls
# Out:
# sample_data  test.csv

# %% [markdown]
# # Section 2
# Moving on to python
