# %% [markdown]
# ## Outline
# * PyTorch
# * What are tensors
# * Initialising, slicing, reshaping tensors
# * Numpy and PyTorch interfacing
# * GPU support for PyTorch + Enabling GPUs on Google Colab
# * Speed comparisons, Numpy -- PyTorch -- PyTorch on GPU
# * Autodiff concepts and application
# * Writing a basic learning loop using autograd
# * Exercises

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Initialise tensors

# %%
x = torch.ones(3, 2)
print(x)
x = torch.zeros(3, 2)
print(x)
x = torch.rand(3, 2)
print(x)
# Out:
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])
# tensor([[0.6527, 0.2842],
#         [0.7299, 0.9204],
#         [0.8290, 0.7110]])

# %%
x = torch.empty(3, 2)
print(x)
y = torch.zeros_like(x)
print(y)
# Out:
# tensor([[1.0785e-35, 0.0000e+00],
#         [3.3631e-44, 0.0000e+00],
#         [       nan, 0.0000e+00]])
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %%
x = torch.linspace(0, 1, steps=5)
print(x)
# Out:
# tensor([0.0000, 0.2500, 0.5000, 0.7500, 1.0000])

# %%
x = torch.tensor([[1, 2], 
                 [3, 4], 
                 [5, 6]])
print(x)
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %% [markdown]
# ## Slicing tensors

# %%
print(x.size())
print(x[:, 1]) 
print(x[0, :])
# Out:
# torch.Size([3, 2])
# tensor([2, 4, 6])
# tensor([1, 2])

# %%
y = x[1, 1]
print(y)
print(y.item())
# Out:
# tensor(4)
# 4

# %% [markdown]
# ## Reshaping tensors

# %%
print(x)
y = x.view(2, 3)
print(y)
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
y = x.view(6,-1) 
print(y)
# Out:
# tensor([[1],
#         [2],
#         [3],
#         [4],
#         [5],
#         [6]])

# %% [markdown]
# ## Simple Tensor Operations

# %%
x = torch.ones([3, 2])
y = torch.ones([3, 2])
z = x + y
print(z)
z = x - y
print(z)
z = x * y
print(z)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.]])
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])

# %%
z = y.add(x)
print(z)
print(y)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]])

# %%
z = y.add_(x)
print(z)
print(y)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]])

# %% [markdown]
# ## Numpy <> PyTorch

# %%
x_np = x.numpy()
print(type(x), type(x_np))
print(x_np)
# Out:
# <class 'torch.Tensor'> <class 'numpy.ndarray'>
# [[1. 1.]
#  [1. 1.]
#  [1. 1.]]

# %%
a = np.random.randn(5)
print(a)
a_pt = torch.from_numpy(a)
print(type(a), type(a_pt))
print(a_pt)
# Out:
# [-0.2425287   1.06660475 -0.66729297 -0.08658468 -2.49841316]
# <class 'numpy.ndarray'> <class 'torch.Tensor'>
# tensor([-0.2425,  1.0666, -0.6673, -0.0866, -2.4984], dtype=torch.float64)

# %%
np.add(a, 1, out=a)
print(a)
print(a_pt)
# Out:
# [ 0.7574713   2.06660475  0.33270703  0.91341532 -1.49841316]
# tensor([ 0.7575,  2.0666,  0.3327,  0.9134, -1.4984], dtype=torch.float64)

# %%
# %%time
for i in range(100):
  a = np.random.randn(100,100)
  b = np.random.randn(100,100)
  c = np.matmul(a, b)
# Out:
# CPU times: user 126 ms, sys: 81.3 ms, total: 207 ms
# Wall time: 119 ms

# %%
# %%time
for i in range(100):
  a = torch.randn([100, 100])
  b = torch.randn([100, 100])
  c = torch.matmul(a, b)
# Out:
# CPU times: user 30.3 ms, sys: 15.7 ms, total: 46 ms
# Wall time: 26.3 ms

# %%
# %%time
for i in range(10):
  a = np.random.randn(10000,10000)
  b = np.random.randn(10000,10000)
  c = a + b
# Out:
# CPU times: user 1min 27s, sys: 1.51 s, total: 1min 29s
# Wall time: 1min 29s

# %%
# %%time
for i in range(10):
  a = torch.randn([10000, 10000])
  b = torch.randn([10000, 10000])
  c = a + b
# Out:
# CPU times: user 18.4 s, sys: 107 ms, total: 18.5 s
# Wall time: 18.5 s

# %% [markdown]
# ## CUDA support

# %%
print(torch.cuda.device_count())
# Out:
# 1

# %%
print(torch.cuda.device(0))
print(torch.cuda.get_device_name(0))
# Out:
# <torch.cuda.device object at 0x7fd7055ab048>
# Tesla T4

# %%
cuda0 = torch.device('cuda:0')

# %%
a = torch.ones(3, 2, device=cuda0)
b = torch.ones(3, 2, device=cuda0)
c = a + b
print(c)
# Out:
# tensor([[2., 2.],
#         [2., 2.],
#         [2., 2.]], device='cuda:0')

# %%
print(a)
# Out:
# tensor([[1., 1.],
#         [1., 1.],
#         [1., 1.]], device='cuda:0')

# %%
# %%time
for i in range(10):
  a = np.random.randn(10000,10000)
  b = np.random.randn(10000,10000)
  np.add(b, a)
# Out:
# CPU times: user 1min 27s, sys: 789 ms, total: 1min 28s
# Wall time: 1min 28s

# %%
# %%time
for i in range(10):
  a_cpu = torch.randn([10000, 10000])
  b_cpu = torch.randn([10000, 10000])
  b_cpu.add_(a_cpu)
# Out:
# CPU times: user 18.9 s, sys: 44 ms, total: 19 s
# Wall time: 19 s

# %%
# %%time
for i in range(10):
  a = torch.randn([10000, 10000], device=cuda0)
  b = torch.randn([10000, 10000], device=cuda0)
  b.add_(a)
# Out:
# CPU times: user 359 µs, sys: 14 ms, total: 14.3 ms
# Wall time: 19.7 ms

# %%
# %%time
for i in range(10):
  a = np.random.randn(10000,10000)
  b = np.random.randn(10000,10000)
  np.matmul(b, a)
# Out:
# CPU times: user 17min 50s, sys: 3.32 s, total: 17min 54s
# Wall time: 9min 47s

# %%
# %%time
for i in range(10):
  a_cpu = torch.randn([10000, 10000])
  b_cpu = torch.randn([10000, 10000])
  torch.matmul(a_cpu, b_cpu)

# %%
# %%time
for i in range(10):
  a = torch.randn([10000, 10000], device=cuda0)
  b = torch.randn([10000, 10000], device=cuda0)
  torch.matmul(a, b)

# %% [markdown]
# ## Autodiff

# %%
x = torch.ones([3, 2], requires_grad=True)
print(x)

# %%
y = x + 5
print(y)

# %%
z = y*y + 1
print(z)

# %%
t = torch.sum(z)
print(t)

# %%
t.backward()

# %%
print(x.grad)

# %% [markdown]
# $t = \sum_i z_i, z_i = y_i^2 + 1, y_i = x_i + 5$
#
# $\frac{\partial t}{\partial x_i} = \frac{\partial z_i}{\partial x_i} = \frac{\partial z_i}{\partial y_i} \frac{\partial y_i}{\partial x_i} = 2y_i \times 1$
#
#
# At x = 1, y = 6, $\frac{\partial t}{\partial x_i} = 12$

# %%
x = torch.ones([3, 2], requires_grad=True)
y = x + 5
r = 1/(1 + torch.exp(-y))
print(r)
s = torch.sum(r)
s.backward()
print(x.grad)

# %%
x = torch.ones([3, 2], requires_grad=True)
y = x + 5
r = 1/(1 + torch.exp(-y))
a = torch.ones([3, 2])
r.backward(a)
print(x.grad)

# %% [markdown]
# $\frac{\partial{s}}{\partial{x}} = \frac{\partial{s}}{\partial{r}} \cdot \frac{\partial{r}}{\partial{x}}$
#
# For the above code $a$ represents $\frac{\partial{s}}{\partial{r}}$ and then $x.grad$ gives directly $\frac{\partial{s}}{\partial{x}}$

# %% [markdown]
# ## Autodiff example that looks like what we have been doing

# %%
x = torch.randn([20, 1], requires_grad=True)
y = 3*x - 2

# %%
w = torch.tensor([1.], requires_grad=True)
b = torch.tensor([1.], requires_grad=True)

y_hat = w*x + b

loss = torch.sum((y_hat - y)**2)

# %%
print(loss)

# %%
loss.backward()

# %%
print(w.grad, b.grad)

# %% [markdown]
# ## Do it in a loop

# %%
learning_rate = 0.01

w = torch.tensor([1.], requires_grad=True)
b = torch.tensor([1.], requires_grad=True)

print(w.item(), b.item())

for i in range(10):
  
  x = torch.randn([20, 1])
  y = 3*x - 2
  
  y_hat = w*x + b
  loss = torch.sum((y_hat - y)**2)
  
  loss.backward()
  
  with torch.no_grad():
    w -= learning_rate * w.grad
    b -= learning_rate * b.grad
    
    w.grad.zero_()
    b.grad.zero_()

  print(w.item(), b.item())

# %% [markdown]
# ## Do it for a large problem

# %%
# %%time
learning_rate = 0.001
N = 10000000
epochs = 200

w = torch.rand([N], requires_grad=True)
b = torch.ones([1], requires_grad=True)

# print(torch.mean(w).item(), b.item())

for i in range(epochs):
  
  x = torch.randn([N])
  y = torch.dot(3*torch.ones([N]), x) - 2
  
  y_hat = torch.dot(w, x) + b
  loss = torch.sum((y_hat - y)**2)
  
  loss.backward()
  
  with torch.no_grad():
    w -= learning_rate * w.grad
    b -= learning_rate * b.grad
    
    w.grad.zero_()
    b.grad.zero_()

#   print(torch.mean(w).item(), b.item())

# %%
# %%time
learning_rate = 0.001
N = 10000000
epochs = 200

w = torch.rand([N], requires_grad=True, device=cuda0)
b = torch.ones([1], requires_grad=True, device=cuda0)

# print(torch.mean(w).item(), b.item())

for i in range(epochs):
  
  x = torch.randn([N], device=cuda0)
  y = torch.dot(3*torch.ones([N], device=cuda0), x) - 2
  
  y_hat = torch.dot(w, x) + b
  loss = torch.sum((y_hat - y)**2)
  
  loss.backward()
  
  with torch.no_grad():
    w -= learning_rate * w.grad
    b -= learning_rate * b.grad
    
    w.grad.zero_()
    b.grad.zero_()

  #print(torch.mean(w).item(), b.item())
